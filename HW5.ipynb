# %% [markdown]
# Name: James Wang
#
# Course: BMGT404
#
# Section: 0101
#
# Date: 2/26/2024

# %%
import re
import requests 
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt  
import seaborn as sns
import plotly.graph_objects as go

# %%
apple_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/AAPL.html'
microsoft_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/MSFT.html'
nike_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/NKE.html'
target_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/TGT.html'
walgreens_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/WBA.html'

# %%
stock_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/AAPL.html'
stock_page = requests.get(stock_url)
stock_page_soup = BeautifulSoup(stock_page.text, 'html.parser')
    
#Sales/Revenue
stock_data_raw = stock_page_soup.find_all(name = 'td', class_='')
count = 0
data = []
while count != len(stock_data_raw):
    if stock_data_raw[count] = 
        data.append(stock_data_raw[count])
# Out:
# <td class="">383,285</td>

# %%
stock_url = 'https://bmgt402.rhsmith.umd.edu/~jbono/bmgt404/homework5/AAPL.html'
stock_page = requests.get(stock_url)
stock_page_soup = BeautifulSoup(stock_page.text, 'html.parser')
    
#Sales/Revenue
stock_data_raw = stock_page_soup.find_all(name = 'td', class_='')
stock_data_raw = stock_data_raw.applymap(lambda x: str(x).replace
# Out:
# [<td class="">Sales/Revenue</td>,
#  <td class="">383,285</td>,
#  <td class="">394,328</td>,
#  <td class="">365,817</td>,
#  <td class="">274,150</td>,
#  <td class="">259,968</td>,
#  <td><span class="sg_bar" style="height:17.140979083402648px;"></span></td>,
#  <td><span class="sg_bar" style="height:18.076068653506727px;"></span></td>,
#  <td><span class="sg_bar" style="height:24.12012842100992px;"></span></td>,
#  <td><span class="sg_bar" style="height:26px;"></span></td>,
#  <td><span class="sg_bar" style="height:25.271880262116817px;"></span></td>,
#  <td class="">-</td>,
#  <td><span class="sg_bar" style="height:0px;"></span></td>,
#  <td><span class="sg_bar" style="height:2.120978040843917px;"></span></td>,
#  <td><span class="sg_bar" style="height:13px;"></span></td>,
#  <td><span class="sg_bar" style="height:3.0301710901342602px;"></span></td>,
#  <td><span class="sg_bar" style="height:0px;"></span></td>,
#  <td><span class="sg_bar" style="height:0px;"></span></td>,
# ...

# %% [markdown]
# "I pledge on my honor that I have not given nor received any unauthorized assistance on this assignment."
#
# --James Wang
